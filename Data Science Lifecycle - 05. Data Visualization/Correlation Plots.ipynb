# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
params = {'legend.fontsize':20,
         'figure.titlesize':25,
         'figure.figsize':(20,10),
         'axes.labelsize':15,
         'axes.titlesize':20,
         'xtick.labelsize':30,
         'ytick.labelsize':30
         }

plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style('white')

# %matplotlib inline

# %% [markdown]
# ## Scatterplot

# %%
#import dataset
midwest = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/midwest_filter.csv")
midwest.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian  ...  percprof  poppovertyknown  percpovertyknown  \
# 0             98       249  ...  4.355859            63628         96.274777
# 1             19        48  ...  2.870315            10529         99.087145
# 2             35        16  ...  4.488572            14235         94.956974
# 3             46       150  ...  4.197800            30337         98.477569
# 4             14         5  ...  3.367680             4815         82.505140
#
# ...

# %%
# data preparations
categories = np.unique(midwest['category'])
print(categories)

# create colors for categories
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

# draw plot 
plt.figure(figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')

# draw plot for each category
for i, category in enumerate(categories):
    plt.scatter('area', 'poptotal', data=midwest.loc[midwest.category==category, :], s=100, c=colors[i], label=str(category))
    
    
# decorating the plot
plt.title('Scatterplot of midwest Area vs Population', fontsize=25, pad=60)
plt.xlabel(xlabel='Area', fontsize=25, labelpad=50, ha='left', rotation=0)
plt.ylabel(ylabel='Population', fontsize=25, labelpad=50, ha='right', rotation=90)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=20, )
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...
